# %%
import json
import requests
import pandas as pd
from pprint import pprint

# %%
viewed_url = "https://api.nytimes.com/svc/mostpopular/v2/viewed/30.json?api-key=api_key"
emailed_url = "https://api.nytimes.com/svc/mostpopular/v2/emailed/30.json?api-key=api_key"
shared_facebook_url = "https://api.nytimes.com/svc/mostpopular/v2/shared/30/facebook.json?api-key=api_key"

# %%
#Call API viewed

viewed_last30days = requests.get(viewed_url).json()
pprint(viewed_last30days)
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights '
#               'Reserved.',
#  'num_results': 20,
#  'results': [{'abstract': 'Trying to find another avenue to push his baseless '
#                           'election claims, Donald Trump considered installing '
#                           'a loyalist.',
#               'adx_keywords': 'Voter Fraud (Election Fraud);Presidential '
#                               'Election of 2020;United States Politics and '
#                               'Government;Rumors and Misinformation;Conspiracy '
#                               'Theories;Ethics and Official Misconduct;Trump, '
#                               'Donald J;Clark, Jeffrey B (1967- );Rosen, '
#                               'Jeffrey Adam (1958- );Donoghue, Richard P '
#                               '(1967- );Engel, Steven A;Justice '
#                               'Department;Georgia',
#               'asset_id': 100000007563674,
# ...

# %%
#Call API emailed

emailed_last30days = requests.get(emailed_url).json()
pprint(emailed_last30days)
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights '
#               'Reserved.',
#  'num_results': 20,
#  'results': [{'abstract': 'Hours after the United States voted, the president '
#                           'declared the election a fraud — a lie that '
#                           'unleashed a movement that would shatter democratic '
#                           'norms and upend the peaceful transfer of power.',
#               'adx_keywords': 'Presidential Election of 2020;Rumors and '
#                               'Misinformation;Right-Wing Extremism and '
#                               'Alt-Right;Voter Fraud (Election Fraud);Suits '
#                               'and Litigation (Civil);United States Politics '
#                               'and Government;Voting Machines;Attorneys '
#                               'General;Trump, Donald J;Giuliani, Rudolph '
#                               'W;McConnell, Mitch;Clark, Justin Reilly (1975- '
# ...

# %%
#Call API shared facebook

shared_facebook_last30days = requests.get(shared_facebook_url).json()
pprint(shared_facebook_last30days)
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights '
#               'Reserved.',
#  'num_results': 20,
#  'results': [{'abstract': 'The president called it an “economic imperative” to '
#                           'provide more aid for millions of Americans who are '
#                           'struggling to make ends meet as the virus exacts a '
#                           'bruising toll.',
#               'adx_keywords': 'Executive Orders and Memorandums;Food '
#                               'Stamps;Food Insecurity;Minimum Wage;Government '
#                               'Employees;Government Contracts and '
#                               'Procurement;Unemployment Insurance;Collective '
#                               'Bargaining;Coronavirus Aid, Relief, and '
#                               'Economic Security Act (2020);Stimulus '
#                               '(Economic);Coronavirus (2019-nCoV);Workplace '
# ...
