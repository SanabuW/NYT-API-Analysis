# %%
import pymongo
import requests
import json
import time
from datetime import datetime, timedelta
from bs4 import BeautifulSoup
import sys
sys.path.append("../common")
from api_keys_local_SW import nyt_API_key

# %%
# connect to mongodb database
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# create reflections and create collection
db = client.gs_search_db
collection = db.gs_articles

# %%
# define url/search params
# set up utilities/params
# pass API key
api_key = nyt_API_key
search_terms = ["gamestop", "election", "covid", "mars", "tesla"]
begin_date = "20201201"
end_date = "20210220"
current_page_counter = 0
page_count_limit = 50
searchCompleteVar = False
search_term_count = 1

# Request loop
for term in search_terms:
    search_post = {
        }
    articles_list = []
    current_page_counter = 0
    for p in range(0,50):
        # sleep to follow API rules
        time.sleep(6)
        # defining url
        url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={term}&begin_date={begin_date}&end_date={end_date}&page={current_page_counter}&api-key={api_key}'

        # set up exception handling for the call
        try:
            # make request and turn into json object
            requestObject = requests.get(url)
            response = json.loads(requestObject.text)
            print()
            print("The status code is {}".format(requestObject.status_code) + " for page " + str(current_page_counter) + " of: " + term)
            print(requestObject.url[0:-41])
        except:
            # on call error, break from current search term loop and move to next search term
            print()
            print("Invalid results. Moving to next request.")            
            current_page_counter = 0
            break

        if requestObject.status_code == 200:
            if response["response"]["docs"] != []:
            #for each article's docs section
                print(f'Getting responses...')
                for art in response["response"]["docs"]:
                    articles_list.append(art)
                current_page_counter += 1
            else:
                print(f'End of results. Starting new search term query')
                current_page_counter = 0
                break                  
            # check if requests are at their limit for search term
            if current_page_counter == page_count_limit:
                searchCompleteVar = False
                print(f'At final page allowed.')
                current_page_counter = 0
                break

    #add search term
    search_post["search_term"] = term
    #add articles list
    search_post["articles"] = articles_list
    #get hits number
    search_post["hits"] = response["response"]["meta"]["hits"]
    #add to collection
    collection.insert_one(search_post)

    #prep for next search term
    search_term_count += 1
    #move to next search term
    current_page_counter = 0
    #add if clause for 
    print(f'Moving to search term {search_term_count}.')
# Out:
# election&begin_date=20201201&end_date=20210220&page=12
# Getting responses...
#
# The status code is 200 for page 13 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=13
# Getting responses...
#
# The status code is 200 for page 14 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=14
# Getting responses...
#
# The status code is 200 for page 15 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=15
# Getting responses...
#
# The status code is 200 for page 16 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=16
# Getting responses...
#
# The status code is 200 for page 17 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=17
# Getting responses...
#
# The status code is 200 for page 18 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=18
# Getting responses...
#
# The status code is 200 for page 19 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=19
# Getting responses...
#
# The status code is 200 for page 20 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=20
# Getting responses...
#
# The status code is 200 for page 21 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=21
# Getting responses...
#
# The status code is 200 for page 22 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=22
# Getting responses...
#
# The status code is 200 for page 23 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=23
# Getting responses...
#
# The status code is 200 for page 24 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=24
# Getting responses...
#
# The status code is 200 for page 25 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=25
# Getting responses...
#
# The status code is 200 for page 26 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=26
# Getting responses...
#
# The status code is 200 for page 27 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=27
# Getting responses...
#
# The status code is 200 for page 28 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=28
# Getting responses...
#
# The status code is 200 for page 29 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=29
# Getting responses...
#
# The status code is 200 for page 30 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=30
# Getting responses...
#
# The status code is 200 for page 31 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=31
# Getting responses...
#
# The status code is 200 for page 32 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=32
# Getting responses...
#
# The status code is 200 for page 33 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=33
# Getting responses...
#
# The status code is 200 for page 34 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=34
# Getting responses...
#
# The status code is 200 for page 35 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=35
# Getting responses...
#
# The status code is 200 for page 36 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=36
# Getting responses...
#
# The status code is 200 for page 37 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=37
# Getting responses...
#
# The status code is 200 for page 38 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=38
# Getting responses...
#
# The status code is 200 for page 39 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=39
# Getting responses...
#
# The status code is 200 for page 40 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=40
# Getting responses...
#
# The status code is 200 for page 41 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=41
# Getting responses...
#
# The status code is 200 for page 42 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=42
# Getting responses...
#
# The status code is 200 for page 43 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=43
# Getting responses...
#
# The status code is 200 for page 44 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=44
# Getting responses...
#
# The status code is 200 for page 45 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=45
# Getting responses...
#
# The status code is 200 for page 46 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=46
# Getting responses...
#
# The status code is 200 for page 47 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=47
# Getting responses...
#
# The status code is 200 for page 48 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=48
# Getting responses...
#
# The status code is 200 for page 49 of: election
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20201201&end_date=20210220&page=49
# Getting responses...
# At final page allowed.
# Moving to search term 3.
#
# The status code is 200 for page 0 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=0
# Getting responses...
#
# The status code is 200 for page 1 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=1
# Getting responses...
#
# The status code is 200 for page 2 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=2
# Getting responses...
#
# The status code is 200 for page 3 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=3
# Getting responses...
#
# The status code is 200 for page 4 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=4
# Getting responses...
#
# The status code is 200 for page 5 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=5
# Getting responses...
#
# The status code is 200 for page 6 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=6
# Getting responses...
#
# The status code is 200 for page 7 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=7
# Getting responses...
#
# The status code is 200 for page 8 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=8
# Getting responses...
#
# The status code is 200 for page 9 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=9
# Getting responses...
#
# The status code is 200 for page 10 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=10
# Getting responses...
#
# The status code is 200 for page 11 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=11
# Getting responses...
#
# The status code is 200 for page 12 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=12
# Getting responses...
#
# The status code is 200 for page 13 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=13
# Getting responses...
#
# The status code is 200 for page 14 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=14
# Getting responses...
#
# The status code is 200 for page 15 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=15
# Getting responses...
#
# The status code is 200 for page 16 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=16
# Getting responses...
#
# The status code is 200 for page 17 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=17
# Getting responses...
#
# The status code is 200 for page 18 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=18
# Getting responses...
#
# The status code is 200 for page 19 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=19
# Getting responses...
#
# The status code is 200 for page 20 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=20
# Getting responses...
#
# The status code is 200 for page 21 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=21
# Getting responses...
#
# The status code is 200 for page 22 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=22
# Getting responses...
#
# The status code is 200 for page 23 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=23
# Getting responses...
#
# The status code is 200 for page 24 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=24
# Getting responses...
#
# The status code is 200 for page 25 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=25
# Getting responses...
#
# The status code is 200 for page 26 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=26
# Getting responses...
#
# The status code is 200 for page 27 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=27
# Getting responses...
#
# The status code is 200 for page 28 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=28
# Getting responses...
#
# The status code is 200 for page 29 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=29
# Getting responses...
#
# The status code is 200 for page 30 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=30
# Getting responses...
#
# The status code is 200 for page 31 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=31
# Getting responses...
#
# The status code is 200 for page 32 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=32
# Getting responses...
#
# The status code is 200 for page 33 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=33
# Getting responses...
#
# The status code is 200 for page 34 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=34
# Getting responses...
#
# The status code is 200 for page 35 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=35
# Getting responses...
#
# The status code is 200 for page 36 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=36
# Getting responses...
#
# The status code is 200 for page 37 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=37
# Getting responses...
#
# The status code is 200 for page 38 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=38
# Getting responses...
#
# The status code is 200 for page 39 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=39
# Getting responses...
#
# The status code is 200 for page 40 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=40
# Getting responses...
#
# The status code is 200 for page 41 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=41
# Getting responses...
#
# The status code is 200 for page 42 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=42
# Getting responses...
#
# The status code is 200 for page 43 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=43
# Getting responses...
#
# The status code is 200 for page 44 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=44
# Getting responses...
#
# The status code is 200 for page 45 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=45
# Getting responses...
#
# The status code is 200 for page 46 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=46
# Getting responses...
#
# The status code is 200 for page 47 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=47
# Getting responses...
#
# The status code is 200 for page 48 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=48
# Getting responses...
#
# The status code is 200 for page 49 of: covid
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid&begin_date=20201201&end_date=20210220&page=49
# Getting responses...
# At final page allowed.
# Moving to search term 4.
#
# The status code is 200 for page 0 of: mars
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=mars&begin_date=20201201&end_date=20210220&page=0
# Getting responses...
#
# The status code is 200 for page 1 of: mars
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=mars&begin_date=20201201&end_date=20210220&page=1
# Getting responses...
#
# The status code is 200 for page 2 of: mars
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=mars&begin_date=20201201&end_date=20210220&page=2
# Getting responses...
#
# The status code is 200 for page 3 of: mars
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=mars&begin_date=20201201&end_date=20210220&page=3
# Getting responses...
#
# The status code is 200 for page 4 of: mars
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=mars&begin_date=20201201&end_date=20210220&page=4
# Getting responses...
#
# The status code is 200 for page 5 of: mars
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=mars&begin_date=20201201&end_date=20210220&page=5
# Getting responses...
#
# The status code is 200 for page 6 of: mars
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=mars&begin_date=20201201&end_date=20210220&page=6
# Getting responses...
#
# The status code is 200 for page 7 of: mars
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=mars&begin_date=20201201&end_date=20210220&page=7
# Getting responses...
#
# The status code is 200 for page 8 of: mars
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=mars&begin_date=20201201&end_date=20210220&page=8
# End of results. Starting new search term query
# Moving to search term 5.
#
# The status code is 200 for page 0 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=0
# Getting responses...
#
# The status code is 200 for page 1 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=1
# Getting responses...
#
# The status code is 200 for page 2 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=2
# Getting responses...
#
# The status code is 200 for page 3 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=3
# Getting responses...
#
# The status code is 200 for page 4 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=4
# Getting responses...
#
# The status code is 200 for page 5 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=5
# Getting responses...
#
# The status code is 200 for page 6 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=6
# Getting responses...
#
# The status code is 200 for page 7 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=7
# Getting responses...
#
# The status code is 200 for page 8 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=8
# Getting responses...
#
# The status code is 200 for page 9 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=9
# Getting responses...
#
# The status code is 200 for page 10 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=10
# Getting responses...
#
# The status code is 200 for page 11 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=11
# Getting responses...
#
# The status code is 200 for page 12 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=12
# Getting responses...
#
# The status code is 200 for page 13 of: tesla
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=tesla&begin_date=20201201&end_date=20210220&page=13
# End of results. Starting new search term query
# Moving to search term 6.
