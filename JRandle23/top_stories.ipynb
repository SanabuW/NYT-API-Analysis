# %%
import json
import requests 
from config import api_key
from pprint import pprint
import pandas as pd

# %%
# URL for business articles
business_url = "https://api.nytimes.com/svc/topstories/v2/business.json?api-key=WCneLj9e31CN4wBTLqA7RxndRuHC10eZ"

# %%
# API call of top stories in Business
articles_business = requests.get(business_url).json()
pprint(articles_business)
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights '
#               'Reserved.',
#  'last_updated': '2021-02-22T13:26:35-05:00',
#  'num_results': 33,
#  'results': [{'abstract': 'Many big businesses have not set targets for '
#                           'reducing greenhouse gas emissions. Others have weak '
#                           'goals.',
#               'byline': 'By Peter Eavis and Clifford Krauss',
#               'created_date': '2021-02-22T10:15:01-05:00',
#               'des_facet': ['Greenhouse Gas Emissions',
#                             'Corporations',
#                             'Fuel Emissions (Transportation)',
#                             'Boards of Directors',
#                             'Stocks and Bonds',
#                             'Carbon Dioxide',
#                             'Global Warming',
#                             'Alternative and Renewable Energy',
#                             "Standard & Poor's 500-Stock Index",
# ...

# %%
# Retrieve article title, date, and snippet for Bussiness top stories
business_articles_list = articles_business["results"]
num_results = len(articles_list)

print("Top Stories in the Business section")
print(f'Number of Results: {num_results}')
print('---------------------------')

for article in business_articles_list:
    print(f'Date: {article["created_date"]}')
    print(f'Title: {article["title"]}')
    print(f'URL: {article["url"]}')
    print(f'Snippet: {article["abstract"]}')
    print('---------------------------')
# Out:
# Top Stories in the Business section
# Number of Results: 25
# ---------------------------
# Date: 2021-02-22T10:15:01-05:00
# Title: Companies Say They Care About the Climate. Their Actions Fall Short.
# URL: https://www.nytimes.com/2021/02/22/business/energy-environment/corporations-climate-change.html
# Snippet: Many big businesses have not set targets for reducing greenhouse gas emissions. Others have weak goals.
# ---------------------------
# Date: 2021-02-22T13:08:00-05:00
# Title: Why Top Economists Are Citing a Higher-Than-Reported Jobless Rate
# URL: https://www.nytimes.com/2021/02/22/business/economy/unemployment-rate-covid.html
# Snippet: The official rate stood at 6.3% in January, but using an expanded metric, Fed and Treasury officials say it’s closer to 10%.
# ---------------------------
# Date: 2021-02-22T08:45:50-05:00
# Title: MyPillow C.E.O. Mike Lindell Sued by Dominion Over Election Fraud Claims
# ...

# %%
# Politics top stories url
politics_url = "https://api.nytimes.com/svc/topstories/v2/politics.json?api-key=WCneLj9e31CN4wBTLqA7RxndRuHC10eZ"

# %%
# API call of top stories in Politics
articles_politics = requests.get(politics_url).json()
pprint(articles_politics)
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights '
#               'Reserved.',
#  'last_updated': '2020-12-03T09:15:05-05:00',
#  'num_results': 21,
#  'results': [{'abstract': 'Two Republican senators said they would not vote to '
#                           'confirm President Biden’s nominee to head the '
#                           'budget office, further dimming her chances to '
#                           'secure enough support in an evenly divided chamber.',
#               'byline': 'By Emily Cochrane and Alan Rappeport',
#               'created_date': '2021-02-22T13:43:01-05:00',
#               'des_facet': ['Presidential Transition (US)',
#                             'United States Politics and Government',
#                             'Social Media'],
#               'geo_facet': [],
#               'item_type': 'Article',
#               'kicker': '',
#               'material_type_facet': '',
# ...

# %%
# Retrieve article title, date and snipped for top stories in Politics
poli_articles_list = articles_politics["results"]
num_results = len(articles_list)

print("Top Stories in politics")
print(f'Number of Results: {num_results}')
print('---------------------------')


for article in poli_articles_list:
    print(f'Date: {article["created_date"]}')
    print(f'Title: {article["title"]}')
    print(f'URL: {article["url"]}')
    print(f'Snippet: {article["abstract"]}')
    print('---------------------------')
# Out:
# Top Stories in politics
# Number of Results: 25
# ---------------------------
# Date: 2021-02-22T13:43:01-05:00
# Title: Tanden’s Confirmation on Shaky Ground as More Senators Voice Opposition
# URL: https://www.nytimes.com/2021/02/22/us/politics/neera-tanden-confirmation-omb.html
# Snippet: Two Republican senators said they would not vote to confirm President Biden’s nominee to head the budget office, further dimming her chances to secure enough support in an evenly divided chamber.
# ---------------------------
# Date: 2021-02-22T12:30:16-05:00
# Title: Barack Obama and Bruce Springsteen: The Latest Podcast Duo
# URL: https://www.nytimes.com/2021/02/22/arts/obama-springsteen-podcast-spotify.html
# Snippet: Their new show, “Renegades: Born in the USA,” features the 44th president and the musician speaking intimately and expansively on topics like race, fatherhood and the country’s painful divisions.
# ---------------------------
# Date: 2021-02-22T09:57:16-05:00
# ...

# %%
# US top stories URL
us_url = "https://api.nytimes.com/svc/topstories/v2/us.json?api-key=WCneLj9e31CN4wBTLqA7RxndRuHC10eZ"

# %%
# API call of top stories in the US
articles_us = requests.get(us_url).json()
pprint(articles_us)
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights '
#               'Reserved.',
#  'last_updated': '2021-02-21T19:04:37-05:00',
#  'num_results': 26,
#  'results': [{'abstract': 'Twice as many Americans have died as early '
#                           'worst-case projections.',
#               'byline': 'By Julie Bosman',
#               'created_date': '2021-02-21T03:00:13-05:00',
#               'des_facet': ['Coronavirus (2019-nCoV)', 'Deaths (Fatalities)'],
#               'geo_facet': ['United States'],
#               'item_type': 'Article',
#               'kicker': '',
#               'material_type_facet': '',
#               'multimedia': [{'caption': '“We knew that when the door opened, '
#                                          'it was Larry walking in.” Larry '
#                                          'Cummings liked to visit the Side '
#                                          'Door Saloon after work on Mondays.',
# ...

# %%
# Retrieve article title, date and snipped for top stories in the US
us_articles_list = articles_us["results"]
num_results = len(us_articles_list)

print("Top Stories in US")
print(f'Number of Results: {num_results}')
print('---------------------------')


for article in us_articles_list:
    print(f'Date: {article["created_date"]}')
    print(f'Title: {article["title"]}')
    print(f'URL: {article["url"]}')
    print(f'Snippet: {article["abstract"]}')
    print('---------------------------')
# Out:
# Top Stories in US
# Number of Results: 26
# ---------------------------
# Date: 2021-02-21T03:00:13-05:00
# Title: A Ripple Effect of Loss: U.S. Covid Deaths Approach 500,000
# URL: https://www.nytimes.com/2021/02/21/us/coronavirus-deaths-us-half-a-million.html
# Snippet: Twice as many Americans have died as early worst-case projections.
# ---------------------------
# Date: 2021-02-21T17:28:48-05:00
# Title: What a Texas Plumber Faces Now: A State Full of Burst Pipes
# URL: https://www.nytimes.com/2021/02/21/us/texas-plumber-frozen-pipes.html
# Snippet: Since a winter storm and hard freeze swept through the state last week, knocking out power and heat, homeowners have swamped plumbers with urgent repair calls.
# ---------------------------
# Date: 2021-02-21T05:00:16-05:00
# Title: How Texas’ Drive for Energy Independence Set It Up for Disaster
# URL: https://www.nytimes.com/2021/02/21/us/texas-electricity-ercot-blackouts.html
# ...

# %%
# Technology top stories URL
tech_url = "https://api.nytimes.com/svc/topstories/v2/technology.json?api-key=WCneLj9e31CN4wBTLqA7RxndRuHC10eZ"

# %%
# API call of top stories in Technology
articles_tech = requests.get(tech_url).json()
pprint(articles_tech)
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights '
#               'Reserved.',
#  'last_updated': '2021-02-22T12:34:31-05:00',
#  'num_results': 29,
#  'results': [{'abstract': 'A fast-growing market for digital art, ephemera and '
#                           'media is marrying the world’s taste for '
#                           'collectibles with cutting-edge technology.',
#               'byline': 'By Erin Griffith',
#               'created_date': '2021-02-22T03:00:10-05:00',
#               'des_facet': ['Virtual Currency',
#                             'Computers and the Internet',
#                             'Music',
#                             'Bitcoin (Currency)',
#                             'Prices (Fares, Fees and Rates)',
#                             'Collectors and Collections',
#                             'Venture Capital'],
#               'geo_facet': [],
#               'item_type': 'Article',
#               'kicker': '',
# ...

# %%
# Retrieve article title, date and snipped for top stories in Technology
tech_articles_list = articles_tech["results"]
num_results = len(tech_articles_list)

print("Top Stories in Technology")
print(f'Number of Results: {num_results}')
print('---------------------------')


for article in tech_articles_list:
    print(f'Date: {article["created_date"]}')
    print(f'Title: {article["title"]}')
    print(f'URL: {article["url"]}')
    print(f'Snippet: {article["abstract"]}')
    print('---------------------------')
# Out:
# Top Stories in Technology
# Number of Results: 29
# ---------------------------
# Date: 2021-02-22T03:00:10-05:00
# Title: Why an Animated Flying Cat With a Pop-Tart Body Sold for Almost $600,000
# URL: https://www.nytimes.com/2021/02/22/business/nft-nba-top-shot-crypto.html
# Snippet: A fast-growing market for digital art, ephemera and media is marrying the world’s taste for collectibles with cutting-edge technology.
# ---------------------------
# Date: 2021-02-21T14:30:08-05:00
# Title: Airbnb Is Driving Hosts Elsewhere With Costly Pandemic Policies
# URL: https://www.nytimes.com/2021/02/21/technology/airbnb-hosts-pandemic-tensions.html
# Snippet: Hurt by refunds, some are trying to cut the site out of bookings or taking legal action. The company says it is working to reduce tensions.
# ---------------------------
# Date: 2021-02-21T03:00:12-05:00
# Title: China Censors the Internet. So Why Doesn’t Russia?
# ...

# %%
# Opinion top stories URL
opinion_url = "https://api.nytimes.com/svc/topstories/v2/opinion.json?api-key=WCneLj9e31CN4wBTLqA7RxndRuHC10eZ"

# %%
# API call of top stories in Opinions
articles_opinion = requests.get(opinion_url).json()
pprint(articles_opinion)
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights '
#               'Reserved.',
#  'last_updated': '2021-02-20T15:38:43-05:00',
#  'num_results': 25,
#  'results': [{'abstract': 'A reader cites a joke from “Annie Hall” to describe '
#                           'the Republicans’ dilemma.',
#               'byline': '',
#               'created_date': '2021-02-22T11:16:41-05:00',
#               'des_facet': ['United States Politics and Government',
#                             'Elections'],
#               'geo_facet': [],
#               'item_type': 'Article',
#               'kicker': 'letters',
#               'material_type_facet': '',
#               'multimedia': [{'caption': '\xa0',
#                               'copyright': 'Brendan Smialowski/Agence '
#                                            'France-Presse — Getty Images',
#                               'format': 'superJumbo',
#                               'height': 1365,
# ...

# %%
# Retrieve article title, date and snipped for top stories in Opinions
opinions_articles_list = articles_opinion["results"]
num_results = len(opinions_articles_list)

print("Top Stories in US")
print(f'Number of Results: {num_results}')
print('---------------------------')


for article in opinions_articles_list:
    print(f'Date: {article["created_date"]}')
    print(f'Title: {article["title"]}')
    print(f'URL: {article["url"]}')
    print(f'Snippet: {article["abstract"]}')
    print('---------------------------')
# Out:
# Top Stories in US
# Number of Results: 25
# ---------------------------
# Date: 2021-02-22T11:16:41-05:00
# Title: Republican Party’s Future: Stay Loyal to Trump, or Disavow Him?
# URL: https://www.nytimes.com/2021/02/22/opinion/letters/republican-party-trump.html
# Snippet: A reader cites a joke from “Annie Hall” to describe the Republicans’ dilemma.
# ---------------------------
# Date: 2021-02-22T05:00:12-05:00
# Title: What Happens When People Stop Going to the Doctor? We’re About to Find Out
# URL: https://www.nytimes.com/2021/02/22/opinion/medical-care-coronavirus.html
# Snippet: A year of missed preventive medical care is endangering minority communities.
# ---------------------------
# Date: 2021-02-22T05:00:09-05:00
# Title: Just When You Thought Politics Couldn’t Unravel Any Further
# URL: https://www.nytimes.com/2021/02/22/opinion/cruz-texas-politics.html
# Snippet: What happens when “All the King’s Men” meets “National Lampoon’s Vacation”? Nothing good.
# ...

# %%
# Create data frame of business articles 
business_articles_df = pd.DataFrame(business_articles_list)
business_articles_df_cleaned = business_articles_df.drop(columns=["subsection", "uri", "byline", "updated_date",                                                                   "created_date", "org_facet", "per_facet",                                                                        "geo_facet", "multimedia", "short_url",                                                                          "material_type_facet","kicker"],                                                                                  axis=1) 

business_articles_df_cleaned
# Out:
#        section                                              title  \
# 0     business  Companies Say They Care About the Climate. The...
# 1     business  Why Top Economists Are Citing a Higher-Than-Re...
# 2     business  MyPillow C.E.O. Mike Lindell Sued by Dominion ...
# 3     business  Fraud Checks and Errors Slow Small-Business Re...
# 4     business  Congressional Committee Presses Cable Provider...
# 5     business  France Hired McKinsey to Help in the Pandemic....
# 6     business  Why an Animated Flying Cat With a Pop-Tart Bod...
# 7     business  On the Post-Pandemic Horizon, Could That Be … ...
# 8           us  Tanden’s Confirmation on Shaky Ground as More ...
# 9        style                       Candy Gets a Brand Extension
# 10    business               Billion-Dollar Paydays in a Pandemic
# 11       style  Jay-Z and LVMH, Two of the World’s Biggest Bra...
# 12     science  She Beat Cancer at 10. Now She’s Set to Be the...
# ...

# %%
# Create data frame of Politics articles 
poli_articles_df = pd.DataFrame(poli_articles_list)
poli_articles_df_cleaned = poli_articles_df.drop(columns=["subsection", "uri", "byline", "updated_date",                                                                   "created_date", "org_facet", "per_facet",                                                                        "geo_facet", "multimedia", "short_url",                                                                          "material_type_facet", "kicker"],                                                                                 axis=1) 
poli_articles_df_cleaned
# Out:
#      section                                              title  \
# 0         us  Tanden’s Confirmation on Shaky Ground as More ...
# 1       arts  Barack Obama and Bruce Springsteen: The Latest...
# 2         us        Did Washington Just Have an Actual Weekend?
# 3   business  Congressional Committee Presses Cable Provider...
# 4         us  Nevada Is Moving to Vote Before Iowa in 2024. ...
# 5         us  On Federal Appeals Courts, a Spike in Partisan...
# 6         us  Iran Curbs Nuclear Inspectors, but Appears to ...
# 7         us  Tough Sanctions, Then a Mysterious Last-Minute...
# 8         us  The Lost Hours: How Confusion and Inaction at ...
# 9         us                                  Read the document
# 10  business  On the Post-Pandemic Horizon, Could That Be … ...
# 11        us  Democrats’ Big Tent Helped Them Win. Now It Th...
# 12        us  How Democrats Are Already Maneuvering to Shape...
# 13        us  Garland Says as Attorney General He Would Comb...
# ...

# %%
# Create data frame of US articles 
US_articles_df = pd.DataFrame(us_articles_list)
US_articles_df_cleaned = poli_articles_df.drop(columns=["subsection", "uri", "byline", "updated_date",                                                                  "created_date", "org_facet", "per_facet",                                                                        "geo_facet", "multimedia", "short_url",                                                                          "material_type_facet", "kicker"],                                                                                 axis=1) 
US_articles_df_cleaned
# Out:
#      section                                              title  \
# 0         us  Tanden’s Confirmation on Shaky Ground as More ...
# 1       arts  Barack Obama and Bruce Springsteen: The Latest...
# 2         us        Did Washington Just Have an Actual Weekend?
# 3   business  Congressional Committee Presses Cable Provider...
# 4         us  Nevada Is Moving to Vote Before Iowa in 2024. ...
# 5         us  On Federal Appeals Courts, a Spike in Partisan...
# 6         us  Iran Curbs Nuclear Inspectors, but Appears to ...
# 7         us  Tough Sanctions, Then a Mysterious Last-Minute...
# 8         us  The Lost Hours: How Confusion and Inaction at ...
# 9         us                                  Read the document
# 10  business  On the Post-Pandemic Horizon, Could That Be … ...
# 11        us  Democrats’ Big Tent Helped Them Win. Now It Th...
# 12        us  How Democrats Are Already Maneuvering to Shape...
# 13        us  Garland Says as Attorney General He Would Comb...
# ...

# %%
# Create data frame of Technology articles 
tech_articles_df = pd.DataFrame(tech_articles_list)
tech_articles_df_cleaned = poli_articles_df.drop(columns=["subsection", "uri", "byline", "updated_date",                                                                   "created_date", "org_facet", "per_facet",                                                                        "geo_facet", "multimedia", "short_url",                                                                          "material_type_facet", "kicker"],                                                                                 axis=1) 
tech_articles_df_cleaned
# Out:
#      section                                              title  \
# 0         us  Tanden’s Confirmation on Shaky Ground as More ...
# 1       arts  Barack Obama and Bruce Springsteen: The Latest...
# 2         us        Did Washington Just Have an Actual Weekend?
# 3   business  Congressional Committee Presses Cable Provider...
# 4         us  Nevada Is Moving to Vote Before Iowa in 2024. ...
# 5         us  On Federal Appeals Courts, a Spike in Partisan...
# 6         us  Iran Curbs Nuclear Inspectors, but Appears to ...
# 7         us  Tough Sanctions, Then a Mysterious Last-Minute...
# 8         us  The Lost Hours: How Confusion and Inaction at ...
# 9         us                                  Read the document
# 10  business  On the Post-Pandemic Horizon, Could That Be … ...
# 11        us  Democrats’ Big Tent Helped Them Win. Now It Th...
# 12        us  How Democrats Are Already Maneuvering to Shape...
# 13        us  Garland Says as Attorney General He Would Comb...
# ...

# %%
# Create data frame of Opinion articles 
opinions_articles_df = pd.DataFrame(opinions_articles_list)
opinions_articles_df_cleaned = opinions_articles_df.drop(columns=["subsection", "uri", "byline", "updated_date",                                                                   "created_date", "org_facet", "per_facet",                                                                        "geo_facet", "multimedia", "short_url",                                                                          "material_type_facet", "kicker"],                                                                                 axis=1) 

opinions_articles_df_cleaned
# Out:
#     section                                              title  \
# 0   opinion  Republican Party’s Future: Stay Loyal to Trump...
# 1   opinion  What Happens When People Stop Going to the Doc...
# 2   opinion  Just When You Thought Politics Couldn’t Unrave...
# 3   opinion  50 Million Americans Are Unpaid Caregivers. We...
# 4   opinion        Can We Stop Fighting About Charter Schools?
# 5   opinion        Storm Victims Didn’t Bring It on Themselves
# 6   opinion   Lessons on Resilience From Dogs and Dog Sledders
# 7   opinion                             The 4 Great Migrations
# 8   opinion  What This Wave of Anti-Asian Violence Reveals ...
# 9   opinion      Why Texas Republicans Fear the Green New Deal
# 10  opinion             A New Third Party Led by Donald Trump?
# 11  opinion                 Hello? Is There Anybody Out There?
# 12  opinion                         What Are Sperm Telling Us?
# 13  opinion                    The Tale of the Untamable Shrew
# ...
