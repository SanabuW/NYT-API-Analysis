# %%
import json
import requests
import pandas as pd

# %%
viewed_url = "https://api.nytimes.com/svc/mostpopular/v2/viewed/30.json?api-key=UO0KtPw9TJHhMgofDtUHBKCzivb20tkN"
emailed_url = "https://api.nytimes.com/svc/mostpopular/v2/emailed/30.json?api-key=UO0KtPw9TJHhMgofDtUHBKCzivb20tkN"
shared_facebook_url = "https://api.nytimes.com/svc/mostpopular/v2/shared/30/facebook.json?api-key=UO0KtPw9TJHhMgofDtUHBKCzivb20tkN"

# %%
#Call API viewed

viewed_last30days = requests.get(viewed_url).json()
print(viewed_last30days)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights Reserved.', 'num_results': 20, 'results': [{'uri': 'nyt://article/ac12c5dc-2f94-5fda-80d5-307b4f9b4aa2', 'url': 'https://www.nytimes.com/2021/01/22/us/politics/jeffrey-clark-trump-justice-department-election.html', 'id': 100000007563674, 'asset_id': 100000007563674, 'source': 'New York Times', 'published_date': '2021-01-22', 'updated': '2021-01-25 07:32:43', 'section': 'U.S.', 'subsection': 'Politics', 'nytdsection': 'u.s.', 'adx_keywords': 'Voter Fraud (Election Fraud);Presidential Election of 2020;United States Politics and Government;Rumors and Misinformation;Conspiracy Theories;Ethics and Official Misconduct;Trump, Donald J;Clark, Jeffrey B (1967- );Rosen, Jeffrey Adam (1958- );Donoghue, Richard P (1967- );Engel, Steven A;Justice Department;Georgia', 'column': None, 'byline': 'By Katie Benner', 'type': 'Article', 'title': 'Trump and Justice Dept. Lawyer Said to Have Plotted to Oust Acting At
# ...

# %%
#Call API emailed

emailed_last30days = requests.get(emailed_url).json()
print(emailed_last30days)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights Reserved.', 'num_results': 20, 'results': [{'uri': 'nyt://article/843f7250-9838-5c56-af37-5ca686d7f5a6', 'url': 'https://www.nytimes.com/2021/01/31/us/trump-election-lie.html', 'id': 100000007563821, 'asset_id': 100000007563821, 'source': 'New York Times', 'published_date': '2021-01-31', 'updated': '2021-02-12 14:04:08', 'section': 'U.S.', 'subsection': '', 'nytdsection': 'u.s.', 'adx_keywords': 'Presidential Election of 2020;Rumors and Misinformation;Right-Wing Extremism and Alt-Right;Voter Fraud (Election Fraud);Suits and Litigation (Civil);United States Politics and Government;Voting Machines;Attorneys General;Trump, Donald J;Giuliani, Rudolph W;McConnell, Mitch;Clark, Justin Reilly (1975- );Montgomery, Dennis Lee (1953- );McInerney, Thomas G;Gosar, Paul (1958- );Barr, William P;Kobach, Kris W;Paxton, Ken;Kremer, Amy;Kremer, Kylie Jane;Lindell, Mike;Cipollone, Pat A;Women for America First;Do
# ...

# %%
#Call API shared facebook

shared_facebook_last30days = requests.get(shared_facebook_url).json()
print(shared_facebook_last30days)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights Reserved.', 'num_results': 20, 'results': [{'uri': 'nyt://article/7800ff38-9ff0-538d-a099-e2af0c5b11a3', 'url': 'https://www.nytimes.com/2021/01/22/business/biden-food-stamps-stimulus-checks.html', 'id': 100000007564527, 'asset_id': 100000007564527, 'source': 'New York Times', 'published_date': '2021-01-22', 'updated': '2021-01-23 10:23:31', 'section': 'Business', 'subsection': '', 'nytdsection': 'business', 'adx_keywords': 'Executive Orders and Memorandums;Food Stamps;Food Insecurity;Minimum Wage;Government Employees;Government Contracts and Procurement;Unemployment Insurance;Collective Bargaining;Coronavirus Aid, Relief, and Economic Security Act (2020);Stimulus (Economic);Coronavirus (2019-nCoV);Workplace Hazards and Violations;Federal Aid (US);United States Economy;United States Politics and Government;Biden, Joseph R Jr', 'column': None, 'byline': 'By Jim Tankersley and Alan Rappeport', 'ty
# ...
