# %%
# Import libraries
import pandas as pd
import requests
import json
import time
import re
import datetime as dt
from scipy.stats import linregress
import matplotlib.pyplot as plt
from pprint import pprint
import sys
# This must be changed if exported to .py file
sys.path.append("../common")
from api_keys_local_SW import nyt_API_key

# %%
# import JSON as object
with open('test/articlesearch_gamestop_202102.json', encoding="UTF-8") as j:
  json_data = json.load(j)

# %%
# Output: {'name': 'Bob', 'languages': ['English', 'Fench']}
pprint(json_data["response"])
# Out:
#                           'width': 4500},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'threeByTwoMediumAt2X',
#                            'height': 1000,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'threeByTwoMediumAt2X',
#                            'subtype': 'threeByTwoMediumAt2X',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-threeByTwoMediumAt2X.jpg',
#                            'width': 1500},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'threeByTwoSmallAt2X',
#                            'height': 400,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'threeByTwoSmallAt2X',
#                            'subtype': 'threeByTwoSmallAt2X',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-threeByTwoSmallAt2X.jpg',
#                            'width': 600},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'articleInline',
#                            'height': 127,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'articleInline',
#                            'subtype': 'articleInline',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-articleInline.jpg',
#                            'width': 190},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'hpSmall',
#                            'height': 109,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'hpSmall',
#                            'subtype': 'hpSmall',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-hpSmall.jpg',
#                            'width': 163},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'blogSmallInline',
#                            'height': 101,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'blogSmallInline',
#                            'subtype': 'blogSmallInline',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-blogSmallInline.jpg',
#                            'width': 151},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'mediumFlexible177',
#                            'height': 118,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'mediumFlexible177',
#                            'subtype': 'mediumFlexible177',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-mediumFlexible177.jpg',
#                            'width': 177},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSmall',
#                            'height': 281,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSmall',
#                            'subtype': 'videoSmall',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSmall.jpg',
#                            'width': 500},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoHpMedium',
#                            'height': 211,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoHpMedium',
#                            'subtype': 'videoHpMedium',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoHpMedium.jpg',
#                            'width': 375},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine600',
#                            'height': 338,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine600',
#                            'subtype': 'videoSixteenByNine600',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine600.jpg',
#                            'width': 600},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine540',
#                            'height': 304,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine540',
#                            'subtype': 'videoSixteenByNine540',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine540.jpg',
#                            'width': 540},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine495',
#                            'height': 278,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine495',
#                            'subtype': 'videoSixteenByNine495',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine495.jpg',
#                            'width': 495},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine390',
#                            'height': 219,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine390',
#                            'subtype': 'videoSixteenByNine390',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine390.jpg',
#                            'width': 390},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine1050',
#                            'height': 591,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine1050',
#                            'subtype': 'videoSixteenByNine1050',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine1050.jpg',
#                            'width': 1050},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine480',
#                            'height': 270,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine480',
#                            'subtype': 'videoSixteenByNine480',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine480.jpg',
#                            'width': 480},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine310',
#                            'height': 174,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine310',
#                            'subtype': 'videoSixteenByNine310',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine310.jpg',
#                            'width': 310},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine225',
#                            'height': 126,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine225',
#                            'subtype': 'videoSixteenByNine225',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine225.jpg',
#                            'width': 225},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine96',
#                            'height': 54,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine96',
#                            'subtype': 'videoSixteenByNine96',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine96.jpg',
#                            'width': 96},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine3000',
#                            'height': 1688,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine3000',
#                            'subtype': 'videoSixteenByNine3000',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine3000.jpg',
#                            'width': 3000},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine768',
#                            'height': 432,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine768',
#                            'subtype': 'videoSixteenByNine768',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine768.jpg',
#                            'width': 768},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNine150',
#                            'height': 84,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNine150',
#                            'subtype': 'videoSixteenByNine150',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNine150.jpg',
#                            'width': 150},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoSixteenByNineJumbo1600',
#                            'height': 900,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoSixteenByNineJumbo1600',
#                            'subtype': 'videoSixteenByNineJumbo1600',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoSixteenByNineJumbo1600.jpg',
#                            'width': 1600},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'miniMoth',
#                            'height': 70,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'miniMoth',
#                            'subtype': 'miniMoth',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-miniMoth.jpg',
#                            'width': 151},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'windowsTile336H',
#                            'height': 336,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'windowsTile336H',
#                            'subtype': 'windowsTile336H',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-windowsTile336H.jpg',
#                            'width': 694},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoFifteenBySeven1305',
#                            'height': 609,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoFifteenBySeven1305',
#                            'subtype': 'videoFifteenBySeven1305',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoFifteenBySeven1305.jpg',
#                            'width': 1305},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'videoFifteenBySeven2610',
#                            'height': 1218,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'videoFifteenBySeven2610',
#                            'subtype': 'videoFifteenBySeven2610',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-videoFifteenBySeven2610.jpg',
#                            'width': 2610},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'facebookJumbo',
#                            'height': 550,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'facebookJumbo',
#                            'subtype': 'facebookJumbo',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-facebookJumbo.jpg',
#                            'width': 1050},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'watch308',
#                            'height': 348,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'watch308',
#                            'subtype': 'watch308',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-watch308.jpg',
#                            'width': 312},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'watch268',
#                            'height': 303,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'watch268',
#                            'subtype': 'watch268',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-watch268.jpg',
#                            'width': 272},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'verticalTwoByThree735',
#                            'height': 1103,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'verticalTwoByThree735',
#                            'subtype': 'verticalTwoByThree735',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-verticalTwoByThree735.jpg',
#                            'width': 735},
#                           {'caption': None,
#                            'credit': None,
#                            'crop_name': 'mobileMasterAt3x',
#                            'height': 1200,
#                            'legacy': {},
#                            'rank': 0,
#                            'subType': 'mobileMasterAt3x',
#                            'subtype': 'mobileMasterAt3x',
#                            'type': 'image',
#                            'url': 'images/2021/02/04/business/04economy-briefing-markets/merlin_171412242_4f224a62-0b32-403a-b2b0-a6738136fae6-mobileMasterAt3x.jpg',
#                            'width': 1800}],
#            'news_desk': 'Business',
#            'print_page': '4',
#            'print_section': 'B',
#            'pub_date': '2021-02-04T12:09:41+0000',
#            'section_name': 'Business Day',
#            'snippet': 'It was the third crash in four trading sessions for the '
#                       'stock. Other so-called meme stocks fell as well.',
#            'source': 'The New York Times',
#            'type_of_material': 'News',
#            'uri': 'nyt://article/e2218b55-4912-5de8-be96-3570f3a725ce',
#            'web_url': 'https://www.nytimes.com/2021/02/04/business/gamestop-stock.html',
#            'word_count': 579}],
#  'meta': {'hits': 135, 'offset': 0, 'time': 34}}

# %%
main_headline = json_data["response"]["docs"][0]["headline"]["main"]
print(main_headline)
# Out:
# The Hopes That Rose and Fell With GameStop

# %%
# set up utilities/params
# MAX 5 terms in search terms list
# MAX 30 pages per term
# SLEEP AT 6
api_key = nyt_API_key
search_term = "gamestop"
#search_term_l = ["gamestop", "term2", "term3", "term4", "term5"]
begin_date = "20201101"
current_page_counter = 0
page_count_limit = 30

# set up lists to append to
abstract_l = []
web_url_l = []
main_headline_l = []
keywords_l = []
pub_date_l =  []
document_type_l = []
type_of_material_l = []
nyt_id_l = []
word_count_l = []


# for each search term??
# for each query result page
#CHANGE RANGE TO ~30 FOR LIVE RUN
for x in range (0,2):
    # sleep to follow API rules
    time.sleep(6)
    url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={search_term}&begin_date={begin_date}&page={current_page_counter}&api-key={api_key}'
    try:
        # make query
        requestObject = requests.get(url)
        response = json.loads(requestObject.text)
        print()
        print("The status code is {}".format(requestObject.status_code) + " for page " + str(current_page_counter) + " of: gamestop")
        print(requestObject.url[0:-41])
    except:
        print()
        print("Invalid results. Moving to next request.")             
        pageHitCount = 0
        break
    if requestObject.status_code == 200:
        #for each article's docs section
        for x in response["response"]["docs"]:
            abstract_l.append(x["abstract"])
            web_url_l.append(x["web_url"])
            main_headline_l.append(x["headline"]["main"])
            pub_date_l.append(x["pub_date"])
            document_type_l.append(x["document_type"])
            type_of_material_l.append(x["type_of_material"])
            nyt_id_l.append(x["_id"])
            word_count_l.append(x["word_count"])
            #find keywords
            tuple_list = []
            for ky in x["keywords"]:
                tuple_list.append(ky["value"])
            keywords_l.append(tuple(tuple_list))
        #loop for this article is finished
        #increase offset
        current_page_counter += 1
        #loop for this page is finished
    #check for done condition
    if current_page_counter > page_count_limit:
        #if done, break out of loop
        break

# keywords_l = []
# for x in artlist:
#     tuple_list = []
#     count = x["keywords"]
#     for y in count:
#         tuple_list.append(y["value"])
#     keywords_l.append(tuple(tuple_list))

#get hits
hits = response["response"]["meta"]["hits"]
# Out:
# The status code is 200 for page 0 of: gamestop
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=gamestop&begin_date=20201101&page=0
#
# The status code is 200 for page 1 of: gamestop
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=gamestop&begin_date=20201101&page=1

# %%
#append to bottom of series practice
#create dataframe
search_df = pd.DataFrame(columns = [
    "abstract",
    "web_url",
    "main_headline",
    "keywords",
    "pub_date",
    "document_type",
    "type_of_material",
    "nyt_id",
    "word_count",
    "search_hits"
    ]) 

search_df["abstract"] = abstract_l
search_df["web_url"] = web_url_l
search_df["main_headline"] = main_headline_l
search_df["keywords"] = keywords_l
search_df["pub_date"] = pub_date_l
search_df["document_type"] = document_type_l
search_df["type_of_material"] = type_of_material_l
search_df["nyt_id"] = nyt_id_l
search_df["word_count"] = word_count_l
search_df["search_hits"] = hits

#show dataframe
search_df
# Out:
#                                              abstract  \
# 0   Fueled by amateur traders and online enthusias...
# 1   On Thursday, the House Financial Services Comm...
# 2   Keith Gill, known on YouTube as Roaring Kitty ...
# 3   The questions lawmakers should ask at a hearin...
# 4   The trader who pumped up the stock on the inte...
# 5   What began as a story about Reddit versus Wall...
# 6   Analysts warn that low-interest rates are prom...
# 7   Lawmakers at a congressional hearing kept comi...
# 8   In a House Financial Services Committee hearin...
# 9   It was the third crash in four trading session...
# 10  Keith Gill was an early endorser of GameStop o...
# 11  Believe it or not, there are real-world financ...
# 12  They may have lost their bet. But they haven’t...
# 13  We can’t beat Wall Street at its own zero-sum ...
# 14  The frenzy for the troubled retailer’s stock h...
# 15  Signs of irrational exuberance abound. Stay so...
# 16                 GameStop takes markets for a ride.
# 17  Some investors may have notched tens of thousa...
# 18  After a crazy run-up, the price dropped 72 per...
# 19  From the populist right to the socialist left,...
#
#                                               web_url  \
# 0   https://www.nytimes.com/2021/02/07/business/ga...
# 1   https://www.nytimes.com/video/us/politics/1000...
# 2   https://www.nytimes.com/video/business/1000000...
# 3   https://www.nytimes.com/2021/02/18/business/de...
westbrook, Russell', 'Financial Brokers', 'House Financial Services Committee'), ('Short Selling', 'Hedge Funds', 'Citadel Investment Group', 'GameStop Corporation', 'House Committee on Financial Services', 'Melvin Capital Management LP', 'Reddit Inc', 'Robinhood Financial LLC', 'Gill, Keith (1986- )', 'Huffman, Steve (1983- )', 'Tenev, Vladimir'), ('Computer and Video Games', 'Computers and the Internet', 'Social Media', 'Stocks and Bonds', 'Hedge Funds', 'Shopping and Retail', 'GameStop Corporation', 'Reddit Inc'), ('Federal Reserve System', 'Banking and Financial Institutions', 'Interest Rates', 'United States Economy', 'Coronavirus (2019-nCoV)', 'Stocks and Bonds', 'GameStop Corporation', 'Reddit Inc', 'Powell, Jerome H'), ('United States Politics and Government', 'House Financial Services Committee', 'GameStop Corporation', 'Citadel Investment Group', 'Melvin Capital Management LP', 'Reddit Inc', 'Robinhood Financial LLC', 'Gill, Keith (1986- )', 'Griffin, Kenneth C', 'Huffman, Steve (1983- )', 'Tenev, Vladimir'), ('Hedge Funds', 'Computer and Video Games', 'GameStop Corporation', 'Melvin Capital Management LP', 'House Committee on Financial Services'), ('Stocks and Bonds', 'GameStop Corporation'), ('Gill, Keith (1986- )', 'GameStop Corporation', 'Massachusetts Mutual Life Insurance Co', 'Regulation and Deregulation of Industry', 'Stocks and Bonds', 'Securities and Commodities Violations', 'Massachusetts'), ('Stocks and Bonds', 'Citadel Investment Group', 'Depository Trust and Clearing Corporation', 'GameStop Corporation', 'Reddit Inc', 'Robinhood Financial LLC', 'Musk, Elon', 'Tenev, Vladimir'), ('GameStop Corporation', 'Reddit Inc', 'Stocks and Bonds', 'Banking and Financial Institutions', 'Hedge Funds', 'Gill, Keith (1986- )'), ('Banking and Financial Institutions', 'Financial Brokers', 'United States Economy', 'Citadel Investment Group', 'GameStop Corporation', 'Biden, Joseph R Jr', 'Stocks and Bonds'), ('GameStop Corporation', 'Stocks and Bonds', 'Computer and Video Games', 'E-Commerce', 'Shopping and Retail', 'Company Reports', 'Coronavirus (2019-nCoV)', 'Short Selling', 'United States'), ('Stocks and Bonds', 'GameStop Corporation', 'Hedge Funds', 'Banking and Financial Institutions', 'Financial Brokers', 'Blockbuster Inc', 'Charles Schwab Corporation', 'Facebook Inc', 'Long Term Capital Management LP'), ('Stocks and Bonds', 'Computer and Video Games', 'GameStop Corporation'), ('GameStop Corporation', 'Stocks and Bonds', 'Income Tax', 'Capital Gains Tax', 'Federal Taxes (US)', 'Tax Preparers and Preparation', 'Personal Finances', 'Robinhood Financial LLC'), ('GameStop Corporation', 'Stocks and Bonds', 'Hedge Funds', 'Reddit Inc', 'Financial Brokers'), ('United States Politics and Government', 'Banking and Financial Institutions', 'United States Economy', 'Regulation and Deregulation of Industry', 'Democratic Party', 'GameStop Corporation', 'Reddit Inc', 'Republican Party', 'Robinhood Financial LLC', 'Cruz, Ted', 'Ocasio-Cortez, Alexandria', 'Stocks and Bonds', 'Hedge Funds')]

# %%
# save results to csv
search_df.to_csv("saved_gs.csv", encoding="cp1252")

# %% [markdown]
# # Begin Transform

# %%
#load csv results

# %%
# Reform dates to add "ending on week x"
# name "weekly_container"
